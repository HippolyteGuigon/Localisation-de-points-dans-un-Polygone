# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from shapely.geometry.polygon import LinearRing, Polygon
from matplotlib import pyplot
from shapely.geometry.polygon import LinearRing, Polygon

# %%
#Entrer une liste de tuples avec chacune des deux coordonnées

def polygon(point, test_point):
    poly = Polygon(point)
    x,y = poly.exterior.xy
    
    ring = LinearRing(point)
    
    x, y = ring.xy
    u = max(x)
    v = max(y)
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111)
    ax.plot(x, y, color='#6699cc', alpha=0.7,
    linewidth=3, solid_capstyle='round', zorder=2)
    ax.scatter(test_point[0], test_point[1], color='red', alpha=0.7)
    ax.plot((test_point[0], max(x)+1), (test_point[1], max(y)+1), '-', color="green")
    ax.set_title('Polygône', fontsize=15)
    
def line_intersection(line1, line2):
    xdiff = (line1[0][0] - line1[1][0], line2[0][0] - line2[1][0])
    ydiff = (line1[0][1] - line1[1][1], line2[0][1] - line2[1][1]) #Typo was here

    def det(a, b):
        return a[0] * b[1] - a[1] * b[0]

    div = det(xdiff, ydiff)
    if div == 0:
        raise Exception('lines do not intersect')

    d = (det(*line1), det(*line2))
    x = det(d, xdiff) / div
    y = det(d, ydiff) / div
    return x, y

# %%
polygon([(0, 0), (0, 1), (1, 2), (5, 3)], (1, 1.4))

# %%
polygon([(0, 0), (0, 1), (1, 2), (5, 3)], (0, 1.4))

# %%
poly = Polygon([(0, 0), (0, 1), (1, 2), (5, 3)])
x,y = poly.exterior.xy
ring = LinearRing([(0, 0), (0, 1), (1, 2), (5, 3)])
    
x, y = ring.xy
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.plot(x, y, color='#6699cc', alpha=0.7,
linewidth=3, solid_capstyle='round', zorder=2)
ax.scatter(0, 1.4, color='red', alpha=0.7)
ax.plot((0, max(x)+1), (1.4, max(y)+1), '-', color="green")
ax.set_title('Polygône', fontsize=15);

# %%
x
# Out:
# array('d', [0.0, 0.0, 1.0, 5.0, 0.0])

# %%
y
# Out:
# array('d', [0.0, 1.0, 2.0, 3.0, 0.0])

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 1000)
f = np.arange(0, 1000)
g = np.sin(np.arange(0, 10, 0.01) * 2) * 1000

plt.plot(x, f, '-')
plt.plot(x, g, '-')

idx = np.argwhere(np.diff(np.sign(f - g))).flatten()
plt.plot(x[idx], f[idx], 'ro')
plt.show()

# %%
x
# Out:
# array('d', [0.0, 0.0, 1.0, 5.0, 0.0])

# %%
from __future__ import division 

def line(p1, p2):
    A = (p1[1] - p2[1])
    B = (p2[0] - p1[0])
    C = (p1[0]*p2[1] - p2[0]*p1[1])
    return A, B, -C

def intersection(L1, L2):
    D  = L1[0] * L2[1] - L1[1] * L2[0]
    Dx = L1[2] * L2[1] - L1[1] * L2[2]
    Dy = L1[0] * L2[2] - L1[2] * L2[0]
    if D != 0:
        x = Dx / D
        y = Dy / D
        return x,y
    else:
        return False

# %%
L1 = line([0,1], [1,0])
L2 = line([2,3], [0,4])

R = intersection(L1, L2)
if R:
    print("Intersection detected:", R)
else:
    print("No single intersection point detected")
# Out:
# Intersection detected: (-6.0, 7.0)
